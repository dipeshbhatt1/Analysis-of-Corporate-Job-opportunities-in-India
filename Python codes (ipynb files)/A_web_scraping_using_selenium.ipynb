# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

# %%
path = 'C:\\Users\\R\\Desktop\\MASAI\\PROJECT\\chromedriver.exe'

# %%
browser = webdriver.Chrome(path)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_7816\217355859.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path)

# %%
link = 'https://www.instahyre.com/search-jobs?company_size=0&isLandingPage=true&location=Anywhere+in+India&offset=0&search=true'
browser.get(link)

# %%
parent = browser.current_window_handle

# %%
Job_list = []

for page in range(2):
    view_button = browser.find_elements(By.ID, "interested-btn")
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])

        try:
            designation = browser.find_element(By.XPATH, ".//h1[@class = 'ng-binding']").text
        except:
            designation = ''
        try:
            company_name = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/h2").text
        except:
            company_name = ''
        try:
            location = browser.find_element(By.XPATH, ".//*[@id='floating-header']/div[1]/div/span[1]").text
        except:
            location = ''
        try:
            estab_year = browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[1]").text
        except:
            estab_year = ''
        try:
            employees_count =  browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[2]").text
        except:
            employees_count = ''
        try:
            job_description =  browser.find_element(By.XPATH, ".//p[@class='ng-binding']").text
        except:
            job_description = ''
        try:
            skills = browser.find_element(By.XPATH, "//*[@id='job-skills-description']").text
        except:
            skills = ''
        try:
            hr_name = browser.find_element(By.CLASS_NAME, "rec-info").text
        except:
            hr_name = ''
        try:
            experience_req = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/div/span[2]").text
        except:
            experience_req = ''
        try:
            emp_overall_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[1]/div[2]/span[2]').text
        except:
            emp_overall_rating = ''
        try:
            emp_wl_bal_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[2]/div[2]/span[2]').text
        except:
            emp_wl_bal_rating = ''
        try:
            emp_salary_n_benefits_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[3]/div[2]/span[2]').text
        except:
            emp_salary_n_benefits_rating = ''
        try:
            emp_comp_culture_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[4]/div[2]/span[2]').text
        except:
            emp_comp_culture_rating = ''
        try:
            emp_career_growth_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[5]/div[2]/span[2]').text
        except:
            emp_career_growth_rating = ''
        try:
            emp_diversity_n_inclusion_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[6]/div[2]/span[2]').text
        except:
            emp_diversity_n_inclusion_rating = ''
        try:
            emp_likely_to_recomm_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[7]/div[2]/span[2]').text
        except:
            emp_likely_to_recomm_rating = ''

        job_details = {'designation':designation, 'company_name':company_name,'location':location, 'estab_year':estab_year,
                       'employees_count':employees_count, 'job_description': job_description, 'skills':skills, 'hr_name':hr_name,
                      'experience_req':experience_req, 'emp_overall_rating':emp_overall_rating,'emp_wl_bal_rating':emp_wl_bal_rating,
                      'emp_salary_n_benefits_rating':emp_salary_n_benefits_rating, 'emp_comp_culture_rating':emp_comp_culture_rating,
                      'emp_career_growth_rating':emp_career_growth_rating,'emp_diversity_n_inclusion_rating':emp_diversity_n_inclusion_rating,
                      'emp_likely_to_recomm_rating':emp_likely_to_recomm_rating}

        Job_list.append(job_details)
        browser.close()
        browser.switch_to.window(parent)
        
    next_botton = browser.find_element(By.XPATH, './/*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[11]/li[12]')
    next_botton.click()
    time.sleep(5)

# %%
df1 = pd.DataFrame(Job_list)
df1
# Out:
#                                          designation  \
# 0                                Service Ops (Drive)
# 1                           Marketing Intern (Drive)
# 2                        Sr. Revenue Analyst (Drive)
# 3                            Account Manager (Drive)
# 4                Demand Generation Associate (Drive)
# 5                           Process Trainers (Drive)
# 6                     Sr. Operations Analyst (Drive)
# 7                Key Account Manager - Sales (Drive)
# 8                          Operations Intern (Drive)
# 9                Customer Success Manager II (Drive)
# 10                       Key Account Manager (Drive)
# 11               Senior Financial Accountant (Drive)
# 12                               Brand Sales (Drive)
# 13                Fullstack Developer - Java (Drive)
# 14                     Performance Marketing (Drive)
# 15                          Zonal Head Sales (Drive)
# 16                                     DPM 1 (Drive)
# 17                                      QA 1 (Drive)
# 18                                     SDE 1 (Drive)
# 19  Software Development Engineer - IV (iOS) (Drive)
#
#                          company_name                  location  \
# 0                            Cogoport                   Gurgaon
# 1                              Hubilo            Work From Home
# 2                         RingCentral                 Bangalore
# 3                          SquadStack                     Noida
# 4                          SquadStack          Bangalore, Noida
# 5                          SquadStack            Work From Home
# 6                          SquadStack                     Noida
# 7                              Thence                 Bangalore
# 8                               Zenda  Delhi, Hyderabad, Mumbai
# 9                            ZoomInfo                   Chennai
# 10                           Cogoport           Gurgaon, Mumbai
# 11                          EagleView            Work From Home
# 12                             Kutumb         Bangalore, Mumbai
# 13                        LTIMindtree  Bangalore, Delhi, Mumbai
# 14                            mPokket        Bangalore, Kolkata
# 15        Open Financial Technologies            Chennai, Delhi
# 16  Piramal Capital & Housing Finance                 Bangalore
# 17  Piramal Capital & Housing Finance                    Mumbai
# 18  Piramal Capital & Housing Finance                    Mumbai
# 19                             Upstox                    Mumbai
#
#          estab_year           employees_count  \
# 0   Founded in 2016       200 - 500 employees
# 1   Founded in 2015        50 - 200 employees
# 2   Founded in 2003  More than 1000 employees
# 3   Founded in 2014        50 - 200 employees
# 4   Founded in 2014        50 - 200 employees
# 5   Founded in 2014        50 - 200 employees
# 6   Founded in 2014        50 - 200 employees
# 7   Founded in 2012        50 - 200 employees
# 8   Founded in 2021         10 - 50 employees
# 9   Founded in 2000  More than 1000 employees
# 10  Founded in 2016       200 - 500 employees
# 11  Founded in 2008          0 - 10 employees
# 12  Founded in 2020        50 - 200 employees
# 13  Founded in 1996  More than 1000 employees
# 14  Founded in 2016  More than 1000 employees
# 15  Founded in 2017       200 - 500 employees
# 16  Founded in 2017         10 - 50 employees
# 17  Founded in 2017         10 - 50 employees
# 18  Founded in 2017         10 - 50 employees
# 19  Founded in 2010       200 - 500 employees
#
#                                       job_description  \
# 0        Function: Operations → Operations Management
# 1              Function: Marketing → Brand Management
# 2         Function: Operations → Accounting / Finance
# 3   Function: Sales and Business → Sales / Busines...
# 4              Function: Marketing → Online Marketing
# 5   Function: Sales and Business → Sales / Busines...
# 6        Function: Operations → Operations Management
# 7   Function: Sales and Business → Sales / Busines...
# 8     Function: Sales and Business → Customer Service
# 9     Function: Sales and Business → Customer Service
# 10  Function: Sales and Business → Sales / Busines...
# 11        Function: Operations → Accounting / Finance
# 12  Function: Sales and Business → Sales / Busines...
# 13  Function: Software Engineering → Full-Stack De...
# 14             Function: Marketing → Online Marketing
# 15  Function: Sales and Business → Sales / Busines...
# 16  Function: Technical Management → Product Manag...
# 17         Function: Software Engineering → QA / SDET
# 18  Function: Software Engineering → Backend Devel...
# 19  Function: Software Engineering → Mobile Develo...
#
#                                                skills  \
# 0    Data Entry\nDocumentation\nOperations Management
# 1          Digital Marketing\nMarketing Communication
# 2   Accounting\nChartered Accountant\nERP Implemen...
# 3   Key Account Management\nMicrosoft Excel\nSales...
# 4   Business Development\nCRM\nDemand Generation\n...
# 5   BPO Operations\nCorporate Training\nLMS\nSales...
# 6   Data Visualization\nMicrosoft Excel\nOperation...
# 7   Corporate Sales\nKey Account Management\nLinke...
# 8   Customer Interaction\nCustomer Relationship\nC...
# 9   Customer Relationship\nCustomer Service\nKey A...
# 10  Corporate Sales\nDirect Sales\nInbound Logisti...
# 11  Accounting\nAuditing\nChartered Accountant\nDi...
# 12  Brand Management\nBusiness Development\nDigita...
# 13          Angular\nJava\nMicroservices\nSpring Boot
# 14  Content Marketing\nDigital Marketing\nFacebook...
# 15  Channel Sales\nPayment Processing\nRevenue Man...
# 16                                 Product Management
# 17  Automation Testing\nLMS\nLOS\nManual Testing\n...
# 18  Algorithms\nData Structures\nDjango\nFlask\nJa...
# 19                                Swift\nSwiftUI\niOS
#
#                                               hr_name experience_req  \
# 0   Revati Agnihotri\nManager Talent Acquisition\n...      0-2 Years
# 1   Tejashwini Kanashetti\nLead Talent Acquisition...      0-1 Years
# 2    Azhar Ahmed\nTechnical Recruiter\nat RingCentral      2-4 Years
# 3        Marsina Waffa\nTech Recruiter\nat SquadStack      2-5 Years
# 4        Marsina Waffa\nTech Recruiter\nat SquadStack      1-3 Years
# 5        Marsina Waffa\nTech Recruiter\nat SquadStack      1-5 Years
# 6        Marsina Waffa\nTech Recruiter\nat SquadStack      2-4 Years
# 7   Sabari Prasad\nAssistant Manager - Human Resou...      4-8 Years
# 8       Meenal Sharma\nSenior TA Specialist\nat Zenda      0-1 Years
# 9   Vasumathi Govindaraj\nSenior Talent Acquisitio...      2-6 Years
# 10  Revati Agnihotri\nManager Talent Acquisition\n...      1-5 Years
# 11  Kavya Iyer\nTalent Acquisition Specialist\nat ...      3-6 Years
# 12                    Dimpy Mehra\nHead HR\nat Kutumb      3-7 Years
# 13                 Akshata\nRecruiter\nat LTIMindtree      4-6 Years
# 14  Aikya Chakraborty\nTalent Acquisition Manager\...      4-8 Years
# 15  Libin O K\nRecruiter\nat Open Financial Techno...     6-10 Years
# 16       Hr\nHR\nat Piramal Capital & Housing Finance      1-3 Years
# 17       Hr\nHR\nat Piramal Capital & Housing Finance      2-5 Years
# 18       Hr\nHR\nat Piramal Capital & Housing Finance      1-4 Years
# 19  Asutosh Maharana\nSenior Associate, Talent Acq...     6-10 Years
#
#    emp_overall_rating emp_wl_bal_rating emp_salary_n_benefits_rating  \
# 0                 4.2               4.1                          4.3
# 1                 3.8               3.6                            4
# 2                 4.6               4.4                          4.6
# 3                   4               3.7                          3.8
# 4                   4               3.7                          3.8
# 5                   4               3.7                          3.8
# 6                   4               3.7                          3.8
# 7                 4.1               3.6                          3.4
# 8                   5                 5                            5
# 9                 3.9               4.4                          3.8
# 10                4.2               4.1                          4.3
# 11                4.3               3.4                          3.5
# 12                4.9               4.8                          4.9
# 13                3.8               3.7                          3.3
# 14                4.1               3.7                          3.8
# 15
# 16                4.4               4.1                          4.3
# 17                4.4               4.1                          4.3
# 18                4.4               4.1                          4.3
# 19                3.4               3.4                          3.8
#
#    emp_comp_culture_rating emp_career_growth_rating  \
# 0                      4.2                      4.3
# 1                      3.7                      3.5
# 2                      4.6                      4.6
# 3                      4.2                      4.1
# 4                      4.2                      4.1
# 5                      4.2                      4.1
# 6                      4.2                      4.1
# 7                      3.9                        4
# 8                        5                        5
# 9                      4.6                      4.2
# 10                     4.2                      4.3
# 11                     3.5                      3.3
# 12                     4.9                      4.8
# 13                     3.8                      3.7
# 14                     3.8                      4.1
# 15
# 16                     4.4                      4.4
# 17                     4.4                      4.4
# 18                     4.4                      4.4
# 19                     3.5                      3.5
#
#    emp_diversity_n_inclusion_rating emp_likely_to_recomm_rating
# 0                               4.2                           4
# 1                               3.6                         3.4
# 2                               4.8                         4.5
# 3                               4.3                           4
# 4                               4.3                           4
# 5                               4.3                           4
# 6                               4.3                           4
# 7                               4.4                         3.5
# 8                                 5                           5
# 9                               4.3                         3.8
# 10                              4.2                           4
# 11                              3.6                           3
# 12                              4.8                         4.9
# 13                              3.8                           4
# 14                              4.1                         4.5
# 15
# 16                              4.3                         4.5
# 17                              4.3                         4.5
# 18                              4.3                         4.5
# 19                              3.7                         3.6

# %%
df1.to_csv("Job_details500.csv")
